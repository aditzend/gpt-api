# %%
from langchain.document_loaders import UnstructuredFileLoader

# %%
loader = UnstructuredFileLoader("/Users/alexander/Documents/perfil/CVAlexanderDitzend .pdf")

# %%
docs = loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 docs = loader.load()
#
# File ~/clients/yzn/gpt-api/venv/lib/python3.9/site-packages/langchain/document_loaders/unstructured.py:61, in UnstructuredBaseLoader.load(self)
#      59 def load(self) -> List[Document]:
#      60     """Load file."""
# ---> 61     elements = self._get_elements()
#      62     if self.mode == "elements":
#      63         docs: List[Document] = list()
#
# File ~/clients/yzn/gpt-api/venv/lib/python3.9/site-packages/langchain/document_loaders/unstructured.py:95, in UnstructuredFileLoader._get_elements(self)
#      92 def _get_elements(self) -> List:
#      93     from unstructured.partition.auto import partition
# ---> 95     return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# ...

# %%
docs[0].page_content[:400]
